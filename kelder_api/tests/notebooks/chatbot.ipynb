# %%
import os
import dotenv
dotenv.load_dotenv()
os.chdir("../..")

# %%
from src.kelder_api.components.agentic_workflow.graph import AgentWorkflow

agent = AgentWorkflow(fake_transport=True)

# %%
await agent.run("hello")
# Out:
# ChatResponse(message='Mock response')
