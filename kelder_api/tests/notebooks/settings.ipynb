# %% [markdown]
# ### Settings test

# %%
import os
os.chdir("../..")

# %%
from src.kelder_api.configuration.settings import get_settings

# %%
get_settings().model_dump()
# Out:
# /Users/tombramwell/Documents/Kelder App/kelder_api/kelder_api
# ['uv.lock', 'Dockerfile', '.ruff_cache', 'pyproject.toml', 'tests', 'README.md', '.gitignore', '.env', '.venv', 'docker-compose.yml', 'poetry.lock', 'src']
# /Users/tombramwell/Documents/Kelder App/kelder_api/kelder_api/src/kelder_api
# {'redis': {'redis_host': 'localhost',
#   'redis_port': 6379,
#   'stationary_sleep': '10000000',
#   'under_way_sleep': '10000000',
#   'velocity_threshold': '0',
#   'gps_serial_port': '/dev/ttyS0'},
#  'sleep_times': {'UNDER_WAY_SLEEP': 10000000.0,
#   'STATIONARY_SLEEP': 10000000.0,
#   'velocity_threshold': '0',
#   'gps_serial_port': '/dev/ttyS0'},
#  'gps': {'gps_serial_port': '/dev/ttyS0',
#   'gps_baudrate': 9600,
#   'gps_timeout': 1.0,
#   'velocity_threshold': 0.0,
#   'stationary_sleep': '10000000',
#   'under_way_sleep': '10000000'},
#  'compass': {'stationary_sleep': '10000000',
#   'under_way_sleep': '10000000',
#   'velocity_threshold': '0',
# ...
