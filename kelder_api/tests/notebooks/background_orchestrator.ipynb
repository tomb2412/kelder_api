# %% [markdown]
# ### Testing the background orchestrator

# %%
import os

os.chdir("../..")

# %%
from src.kelder_api.components.background_orchestrator.orchestrator import (
    BackgroundTaskManager,
)

task_manager = BackgroundTaskManager()

# %%
task_manager.components
# Out:
# {'GPS': {'instance': <src.kelder_api.components.gps_new.interface.GPSInterface at 0x104942960>,
#   'method': 'stream_serial_data'},
#  'COMPASS': {'instance': <src.kelder_api.components.compass_new.interface.CompassInterface at 0x10550c5c0>,
#   'method': 'read_heading_from_compass'},
#  'VELOCITY': {'instance': <src.kelder_api.components.velocity.service.VelocityCalculator at 0x104532840>,
#   'method': 'calculate_gps_velocity'}}

# %%
await task_manager.run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 await task_manager.run()
#
# File ~/Documents/Kelder App/kelder_api/kelder_api/src/kelder_api/components/background_orchestrator/orchestrator.py:69, in BackgroundTaskManager.run(self)
#      66 vessel_state = VesselState.STATIONARY
#      67 while True:
#      68     # Run the strategy matching the vessel state
# ---> 69     await self.strategies[vessel_state](components = self.components)
#      71     vessel_state = self.calculate_new_state()
#
# File ~/Documents/Kelder App/kelder_api/kelder_api/src/kelder_api/components/background_orchestrator/stationary_strategy.py:21, in StationaryStrategy.execute(self, components)
#      19 @classmethod
#      20 async def execute(self, components: Dict[str, dict]) -> None:
# ---> 21     for sensor in self.required_sensors():
#      22         await getattr(
#      23             components[sensor]["instance"], components[sensor]["method"]
#      24         )()
#      26     for calculator in self.required_calculators():
#
# TypeError: StationaryStrategy.required_sensors() missing 1 required positional argument: 'self'
