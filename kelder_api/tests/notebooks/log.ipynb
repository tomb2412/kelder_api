# %%
import os
os.chdir("../..")

# %%
from datetime import datetime

from src.kelder_api.components.gps_new.interface import GPSInterface
from src.kelder_api.components.velocity.service import VelocityCalculator
from src.kelder_api.components.redis_client.redis_client import RedisClient
from src.kelder_api.components.log.service import LogTracker

redis_client = RedisClient()
gps_interface = GPSInterface(redis_client)
velocity_calculator = VelocityCalculator(
    gps_interface=gps_interface, redis_client=redis_client
)

# %%
log_tracker = LogTracker(gps_interface,redis_client,velocity_calculator)

# %%
await log_tracker.increment_log()
# Out:
# Redis connection error: Error Multiple exceptions: [Errno 111] Connect call failed ('::1', 6379, 0, 0), [Errno 111] Connect call failed ('127.0.0.1', 6379) connecting to localhost:6379.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/.pyenv/versions/kelder_api/lib/python3.12/site-packages/redis/asyncio/connection.py:290, in AbstractConnection.connect(self)
#     289 try:
# --> 290     await self.retry.call_with_retry(
#     291         lambda: self._connect(), lambda error: self.disconnect()
#     292     )
#     293 except asyncio.CancelledError:
#
# File ~/.pyenv/versions/kelder_api/lib/python3.12/site-packages/redis/asyncio/retry.py:59, in Retry.call_with_retry(self, do, fail)
#      58 try:
# ---> 59     return await do()
#      60 except self._supported_errors as error:
#
# File ~/.pyenv/versions/kelder_api/lib/python3.12/site-packages/redis/asyncio/connection.py:723, in Connection._connect(self)
#     722 async with async_timeout(self.socket_connect_timeout):
# --> 723     reader, writer = await asyncio.open_connection(
#     724         **self._connection_arguments()
#     725     )
#     726 self._reader = reader
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/asyncio/streams.py:48, in open_connection(host, port, limit, **kwds)
#      47 protocol = StreamReaderProtocol(reader, loop=loop)
# ---> 48 transport, _ = await loop.create_connection(
#      49     lambda: protocol, host, port, **kwds)
#      50 writer = StreamWriter(transport, protocol, reader, loop)
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/asyncio/base_events.py:1130, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, ssl_shutdown_timeout, happy_eyeballs_delay, interleave, all_errors)
#    1128         # Raise a combined exception so the user can see all
#    1129         # the various error messages.
# -> 1130         raise OSError('Multiple exceptions: {}'.format(
#    1131             ', '.join(str(exc) for exc in exceptions)))
#    1132 finally:
#
# OSError: Multiple exceptions: [Errno 111] Connect call failed ('::1', 6379, 0, 0), [Errno 111] Connect call failed ('127.0.0.1', 6379)
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 await log_tracker.increment_log()
#
# File ~/kelder_api/kelder_api/src/kelder_api/components/log/service.py:58, in LogTracker.increment_log(self)
#      52 async def increment_log(self):
#      53     """
#      54     Private method which uses class wide variables to incement:
#      55     - the total journey time and distance
#      56     - the start time and position the current tack began. -> for drift range
#      57     """
# ---> 58     gps_data, velocity_data = await self._get_sensor_data()
#      60     # If there is no log history at the start of the journey
#      61     if self.start_journey:
#
# File ~/kelder_api/kelder_api/src/kelder_api/components/log/service.py:36, in LogTracker._get_sensor_data(self)
#      34 async def _get_sensor_data(self) -> Tuple[GPSRedisData, GPSVelocity]:
#      35     """Private method to retrieve the latest gps and velocity data for the trip."""
# ---> 36     gps_data =  await self.gps_interface.read_gps_latest(active=True)
#      37     velocity_data = await self.velocity_calculator.read_velocity_latest(active=True)
#      39     inter_measurement_latency = abs((gps_data.timestamp - velocity_data.timestamp.replace(tzinfo=timezone.utc)).total_seconds())
#
# File ~/kelder_api/kelder_api/src/kelder_api/components/gps_new/interface.py:114, in GPSInterface.read_gps_latest(self, active)
#     112 try:
#     113     if active:
# --> 114         return (await self.read_active_gps_measurements())[0]
#     115     else:
#     116         return GPSRedisData(**(await self.redis_client.read_set("GPS"))[0])
#
# File ~/kelder_api/kelder_api/src/kelder_api/components/gps_new/interface.py:177, in GPSInterface.read_active_gps_measurements(self)
#     173 async def read_active_gps_measurements(self) -> List[GPSRedisData]:
#     174     """Returns only active GPS measurements from all history"""
#     175     return [
#     176         GPSRedisData(**active_measurement)
# --> 177         for active_measurement in await self.redis_client.read_set("GPS")
#     178         if active_measurement["status"] == "A"
#     179     ]
#
# File ~/kelder_api/kelder_api/src/kelder_api/components/redis_client/redis_client.py:95, in RedisClient.read_set(self, sensor_id, datetime_range)
#      92 key = f"sensor:ts:{sensor_id}"
#      94 # Get data in time range with scores (timestamps)
# ---> 95 sensor_data = await redis.zrevrangebyscore(
#      96     key,
#      97     max=datetime_range[1].timestamp() if datetime_range else "+inf",
#      98     min=datetime_range[0].timestamp() if datetime_range else "-inf",
#      99     withscores=True,
#     100 )
#     102 results = [json.loads(measurement) for measurement, _ in sensor_data]
#     103 times = [timestamp for _, timestamp in sensor_data]
#
# File ~/.pyenv/versions/kelder_api/lib/python3.12/site-packages/redis/asyncio/client.py:641, in Redis.execute_command(self, *args, **options)
#     639 pool = self.connection_pool
#     640 command_name = args[0]
# --> 641 conn = self.connection or await pool.get_connection()
#     643 if self.single_connection_client:
#     644     await self._single_conn_lock.acquire()
#
# File ~/.pyenv/versions/kelder_api/lib/python3.12/site-packages/redis/asyncio/connection.py:1100, in ConnectionPool.get_connection(self, command_name, *keys, **options)
#    1098 connection = self.get_available_connection()
#    1099 try:
# -> 1100     await self.ensure_connection(connection)
#    1101 except BaseException:
#    1102     await self.release(connection)
#
# File ~/.pyenv/versions/kelder_api/lib/python3.12/site-packages/redis/asyncio/connection.py:1133, in ConnectionPool.ensure_connection(self, connection)
#    1131 async def ensure_connection(self, connection: AbstractConnection):
#    1132     """Ensure that the connection object is connected and valid"""
# -> 1133     await connection.connect()
#    1134     # connections that the pool provides should be ready to send
#    1135     # a command. if not, the connection was either returned to the
#    1136     # pool before all data has been read or the socket has been
#    1137     # closed. either way, reconnect and verify everything is good.
#    1138     try:
#
# File ~/.pyenv/versions/kelder_api/lib/python3.12/site-packages/redis/asyncio/connection.py:298, in AbstractConnection.connect(self)
#     296     raise TimeoutError("Timeout connecting to server")
#     297 except OSError as e:
# --> 298     raise ConnectionError(self._error_message(e))
#     299 except Exception as exc:
#     300     raise ConnectionError(exc) from exc
#
# ConnectionError: Error Multiple exceptions: [Errno 111] Connect call failed ('::1', 6379, 0, 0), [Errno 111] Connect call failed ('127.0.0.1', 6379) connecting to localhost:6379.
