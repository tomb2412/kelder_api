# %%
from datetime import datetime

now = datetime.now()

# %%
print(now)
# Out:
# 2025-09-16 21:40:08.137433

# %%
date_start = datetime(2025, 8, 12, 22, 2, 20, 44437)
date_end = datetime(2025, 8, 12, 22, 2, 21, 44437)

(date_start-date_end).total_seconds()
# Out:
# -1.0
